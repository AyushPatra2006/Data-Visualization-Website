# %%
import pandas as pd
df = pd.read_csv("anime.csv")

# %%
filtereDf = df.loc[df["type"]=='TV'].copy()
filtereDf.drop(filtereDf.tail(3000).index,inplace=True)
filtereDf
# Out:
#       anime_id                                               name  \
# 1         5114                   Fullmetal Alchemist: Brotherhood
# 2        28977                                           Gintama°
# 3         9253                                        Steins;Gate
# 4         9969                                      Gintama&#039;
# 5        32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# ...        ...                                                ...
# 1493       506                                     Glass no Kamen
# 1495       142                             Kamikaze Kaitou Jeanne
# 1498      3358                                           Kure-nai
# 1499        76                        Mahou Shoujo Lyrical Nanoha
# 1501     31722              Nanatsu no Taizai: Seisen no Shirushi
#
#                                                   genre type episodes  rating  \
# 1     Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64    9.26
# ...

# %%
# filteredDf = filteredDf.loc[filteredDf["synopsis"].notna()].copy()
# filteredDf = filteredDf.loc[filteredDf["producers"].notna()].copy()
# filteredDf = filteredDf.loc[filteredDf["studios"].notna()].copy()
# filteredDf.drop(['Unnamed: 0'], axis=1, inplace=True, errors='ignore')

# %%
filtereDf.to_csv("main.csv")

# %%
import csv

# Read CSV file
with open("main.csv") as f:
    reader = csv.reader(f)
    rows = list(reader)

# Build HTML
html = "<html><h1>Browse</h1>{}</html>".format(filtereDf.to_html())

# Write to browse.html
with open("browse.html", "w") as f:
    f.write(html)
